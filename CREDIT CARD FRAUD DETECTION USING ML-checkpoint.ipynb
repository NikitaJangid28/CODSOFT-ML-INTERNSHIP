# %% [markdown]
# # CREDIT CARD FRAUD DETECTION USING ML WITH PYTHON

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

fraud_data= pd.read_csv("creditcardshort1.csv")

# %%
#head() gives you the first few data from dataset
fraud_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
#    Amount  Class
# 0  149.62      0
# 1    2.69      0
# ...

# %%
# tail() gives you the last selected columns from the data
fraud_data.tail(7)
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 153751  99978  0.171595  0.704071 -0.096390 -0.507976  0.773840 -0.445430
# 153752  99979  1.757293  0.321483  0.310697  4.044304 -0.197682  0.153073
# 153753  99980 -0.460128  0.203036  0.469998 -0.877349 -0.333565  1.198391
# 153754  99984  1.930509  0.589877 -0.573178  4.011452  0.646176  0.406016
# 153755  99995 -0.080563  0.840885 -0.085326 -0.606702  0.879790 -0.493156
# 153756  99998 -1.730665  1.302833  0.397864 -0.445631 -0.773382  0.223966
# 153757  99999 -0.309641  0.771215  0.679051 -1.069673  1.414042 -0.379638
#
#               V7        V8        V9       V10       V11       V12       V13  \
# 153751  0.756836 -0.074844  1.246173 -0.544290  1.136295 -2.057177  1.053738
# 153752 -0.383411 -0.089837  0.671431  1.011628 -0.110195 -2.314217  2.695373
# 153753  1.088143 -0.303794  2.153779 -0.467294  0.121614 -3.045554  0.689815
# ...

# %%
#it gives you information about the total null values in row
fraud_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# Amount    0
# Class     0
# dtype: int64

# %%
fraud_data.notnull().sum()
# Out:
# Time      153758
# V1        153758
# V2        153758
# V3        153758
# V4        153758
# V5        153758
# V6        153758
# V7        153758
# V8        153758
# V9        153758
# V10       153758
# V11       153758
# V12       153758
# V13       153758
# V14       153758
# Amount    153758
# Class     153758
# dtype: int64

# %%
#info() gives the complete information of data
print(fraud_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153758 entries, 0 to 153757
# Data columns (total 17 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    153758 non-null  int64
#  1   V1      153758 non-null  float64
#  2   V2      153758 non-null  float64
#  3   V3      153758 non-null  float64
#  4   V4      153758 non-null  float64
#  5   V5      153758 non-null  float64
#  6   V6      153758 non-null  float64
#  7   V7      153758 non-null  float64
#  8   V8      153758 non-null  float64
#  9   V9      153758 non-null  float64
#  10  V10     153758 non-null  float64
#  11  V11     153758 non-null  float64
#  12  V12     153758 non-null  float64
#  13  V13     153758 non-null  float64
#  14  V14     153758 non-null  float64
#  15  Amount  153758 non-null  float64
#  16  Class   153758 non-null  int64
# dtypes: float64(15), int64(2)
# memory usage: 19.9 MB
# None

# %%
# shape tells about the total no. of rows and column
print(fraud_data.shape)
# Out:
# (153758, 17)

# %%
#Describe tells about the description of data statistical
fraud_data.describe()
# Out:
#                 Time             V1             V2             V3  \
# count  153758.000000  153758.000000  153758.000000  153758.000000
# mean    55219.166333      -0.234187       0.045504       0.604016
# std     22658.988461       1.836892       1.620692       1.327202
# min         0.000000     -56.407510     -72.715728     -33.680984
# 25%     39394.000000      -1.021436      -0.539477       0.096945
# 50%     56784.000000      -0.258642       0.119851       0.704860
# 75%     73829.000000       1.164805       0.805848       1.337165
# max     99999.000000       2.401777      18.902453       9.382558
#
#                   V4             V5             V6             V7  \
# count  153758.000000  153758.000000  153758.000000  153758.000000
# mean        0.134835      -0.236612       0.069428      -0.103249
# std         1.352793       1.326851       1.290105       1.195012
# min        -5.519697     -42.147898     -26.160506     -31.764946
# ...

# %%
fraud_data.describe().T
# Out:
#            count          mean           std        min           25%  \
# Time    153758.0  55219.166333  22658.988461   0.000000  39394.000000
# V1      153758.0     -0.234187      1.836892 -56.407510     -1.021436
# V2      153758.0      0.045504      1.620692 -72.715728     -0.539477
# V3      153758.0      0.604016      1.327202 -33.680984      0.096945
# V4      153758.0      0.134835      1.352793  -5.519697     -0.723555
# V5      153758.0     -0.236612      1.326851 -42.147898     -0.873953
# V6      153758.0      0.069428      1.290105 -26.160506     -0.675633
# V7      153758.0     -0.103249      1.195012 -31.764946     -0.598162
# V8      153758.0      0.051217      1.239475 -73.216718     -0.143827
# V9      153758.0     -0.029171      1.131997  -9.462573     -0.685397
# V10     153758.0     -0.030560      1.089857 -22.187089     -0.509589
# V11     153758.0      0.210980      1.050087  -4.049895     -0.546661
# ...

# %%
#it gives amount of fraud and non-fraud data in dataset 
class_names={0:'Not Fraud', 1:'Fraud'}
print(fraud_data.Class.value_counts().rename(index=class_names))
# Out:
# Not Fraud    153428
# Fraud           330
# Name: Class, dtype: int64

# %%
#it gives amount of fraud data in dataset statistical
fraud = fraud_data[fraud_data['Class'] == 1]
print('Amount details of the fraudulent transaction:')
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transaction:
# count     330.000000
# mean      115.783606
# std       233.695450
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       103.397500
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#it gives amount of Non-fraud data in dataset statistical
valid = fraud_data[fraud_data['Class'] == 0]
print('Amount details of the valid/non fraudulent transaction:')
valid.Amount.describe()
# Out:
# Amount details of the valid/non fraudulent transaction:
# count    153428.000000
# mean         88.478632
# std         246.120831
# min           0.000000
# 25%           5.900000
# 50%          22.540000
# 75%          78.850000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
# We will be dividing the dataset into two main groups.One for training and the other for Testing our trained models performance.
from sklearn.model_selection import train_test_split
y= fraud_data["Class"]
x= fraud_data.loc[:,fraud_data.columns !='Class']
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=1/3,random_state=42,stratify=y)

# %%
# Import library for Accuracy score
from sklearn.metrics import accuracy_score

# Import library for Logistic Regression
from sklearn.linear_model import LogisticRegression

# Initialize the logistic Regression Classifier
logisreg=LogisticRegression()

# Train the model using Training Dataset
logisreg.fit(x_train,y_train)

# Prediction output using test data
y_pred=logisreg.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
acc_logisreg=round(accuracy_score(y_test,y_pred)*100,2)
print('Accuracy of Logistic Regression model:',acc_logisreg)
# Out:
# Accuracy of Logistic Regression model: 99.78
# C:\Users\Nikita\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Import library for linear Discriminant Analysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# Initialize the LDA Classifier
model = LinearDiscriminantAnalysis()

# Train the model using Training Dataset
model.fit(x_train,y_train)

# Prediction using test data
y_pred = model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
acc_lda = round(accuracy_score(y_test,y_pred)*100,2)
print('Accuracy of Linear Dicriminant Analysis Classifier:',acc_lda)
# Out:
# Accuracy of Linear Dicriminant Analysis Classifier: 99.89

# %%
# Import library for Decision Tree Classifier
from sklearn.tree import DecisionTreeClassifier

# Initialize the Decision Tree Classifier
model = DecisionTreeClassifier()

# Train the model using Training Dataset
model.fit(x_train, y_train)

# Prediction using the Test Dataset
y_pred= model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
decision_tree_score= accuracy_score(y_test,y_pred) * 100
print('Decision Tree Score:',decision_tree_score)
# Out:
# Decision Tree Score: 99.91220026144812

# %%
# Import library for Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier

# Initialize the Random Forest Classifier
model= RandomForestClassifier()

# Train the model using Training Dataset
model.fit(x_train, y_train)

# Prediction using the Test Dataset
y_pred= model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
RFC_score= accuracy_score(y_test,y_pred) * 100
print('Decision Tree Score:',RFC_score)
# Out:
# Decision Tree Score: 99.9375646303631

# %%
# Import library for Gaussian Naive Bayes 
from sklearn.naive_bayes import GaussianNB

# Initialize the Gaussian Naive Bayes Classifier
model=GaussianNB()

# Train the model using Training Dataset
model.fit(x_train,y_train)

# Prediction using the Test Dataset
y_pred=model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
acc_ganb=round(accuracy_score(y_test,y_pred)*100,2)
print('Accuracy of Gaussian Naive Bayes:',acc_ganb)
# Out:
# Accuracy of Gaussian Naive Bayes: 98.52

# %%
# Import library for Support Vector Machine
from sklearn import svm

# Initialize the Support Vector Machine Classifier
model=svm.SVC()

# Train the model using Training Dataset
model.fit(x_train,y_train)

# Prediction using the Test Dataset
y_pred=model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
acc_svc=round(accuracy_score(y_test,y_pred)*100,2)
print('Accuracy of Support Vector Machine:',acc_svc)
# Out:
# Accuracy of Support Vector Machine: 99.79

# %%
# Import library for K-Nearest Neighbors
from sklearn.neighbors import KNeighborsClassifier

# Initialize the K-Nearest Neighbors Classifier
model=KNeighborsClassifier()

# Train the model using Training Dataset
model.fit(x_train,y_train)

# Prediction using the Test Dataset
y_pred=model.predict(x_test)

# Calculate model accuracy by comparing y_test and y_pred
acc_knn=round(accuracy_score(y_test,y_pred)*100,2)
print('Accuracy of  K Nearest Neighbors:',acc_knn)
# Out:
# C:\Users\Nikita\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Accuracy of  K Nearest Neighbors: 99.8

# %%
# Decison making for the good model algorithm 
models=pd.DataFrame({'Model':['Logistic Regression','Linear Discriminant','Naive Bayes','Decision Tree','Random Forest','Support Vector Machine','K Nearest Neighbors'],'Score':[acc_logisreg,acc_lda ,acc_ganb,decision_tree_score,RFC_score,acc_svc,acc_knn]
})
models.sort_values(by='Score',ascending=False)
# Out:
#                     Model      Score
# 4           Random Forest  99.937565
# 3           Decision Tree  99.912200
# 1     Linear Discriminant  99.890000
# 6     K Nearest Neighbors  99.800000
# 5  Support Vector Machine  99.790000
# 0     Logistic Regression  99.780000
# 2             Naive Bayes  98.520000

# %%
from matplotlib import gridspec
# Correlation matrix
corrmat = fraud_data.corr()
fig = plt.figure(figsize = (10, 5))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train, y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_35588\3551631106.py in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 cm = confusion_matrix(y_train, y_pred)
#       3 cm
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     305     (0, 2, 1, 1)
#     306     """
# --> 307     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     308     if y_type not in ("binary", "multiclass"):
#     309         raise ValueError("%s is not supported" % y_type)
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
# ...

# %%
from sklearn.metrics import confusion_matrix

# Verify the lengths of y_train and y_pred
print("Length of y_train:", len(y_train))
print("Length of y_pred:", len(y_pred))

# Ensure that y_train and y_pred have the same length
if len(y_train) != len(y_pred):
    print("Error: Inconsistent lengths of y_train and y_pred")
else:
    cm = confusion_matrix(y_train, y_pred)
    print("Confusion Matrix:")
    print(cm)
# Out:
# Length of y_train: 102505
# Length of y_pred: 51253
# Error: Inconsistent lengths of y_train and y_pred

# %%
from sklearn.metrics import confusion_matrix

# Print lengths of y_train and y_pred
print("Length of y_train:", len(y_train))
print("Length of y_pred:", len(y_pred))

# Check if lengths match
if len(y_train) == len(y_pred):
    # Build the confusion matrix
    cm = confusion_matrix(y_train, y_pred)
    print("Confusion Matrix:")
    print(cm)
else:
    print("Error: Inconsistent lengths of y_train and y_pred")

# Debugging information
print("First few elements of y_train:", y_train[:51253])
print("First few elements of y_pred:", y_pred[:51253])
# Out:
# Length of y_train: 102505
# Length of y_pred: 51253
# Error: Inconsistent lengths of y_train and y_pred
# First few elements of y_train: 32096     0
# 40165     0
# 20310     0
# 103907    0
# 95791     0
#          ..
# 16204     0
# 11791     0
# 53605     0
# 115051    0
# 106892    0
# Name: Class, Length: 51253, dtype: int64
# First few elements of y_pred: [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     51143
#            1       1.00      0.05      0.10       110
#
#     accuracy                           1.00     51253
#    macro avg       1.00      0.53      0.55     51253
# weighted avg       1.00      1.00      1.00     51253

# %%
# Plotting a Confusion Matrix with Sklearn
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

conf_matrix = confusion_matrix(y_true=y_test, y_pred=y_pred)
vis = ConfusionMatrixDisplay(confusion_matrix=conf_matrix,
display_labels=model.classes_)
vis.plot()
plt.show()

# %%
# Import necessary libraries
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.svm import SVC  # Import your classifier, for example, Support Vector Classifier

prediction = clf.predict(x_test)
# Define and train your classifier
clf = SVC()  # Instantiate the classifier
clf.fit(x_train, y_train)  # Train the classifier with your training data

# Plot the confusion matrix using Seaborn's heatmap
conf_matrix = confusion_matrix(y_test, prediction, labels=clf.classes_)
sns.heatmap(conf_matrix, annot=True, fmt='g', xticklabels=clf.classes_, yticklabels=clf.classes_)
plt.ylabel('Prediction', fontsize=13)
plt.xlabel('Actual', fontsize=13)
plt.title('Confusion Matrix', fontsize=10)
plt.show()
